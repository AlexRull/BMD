# %%
# 1. Введення даних вручну
import pandas as pd
new_df = pd.DataFrame(
{
    "Club name" : ['Barcelona','Real', 'City', 'Liverpool', 'Bayern'],
    "City" : ['Barcelona',  'Madrid', 'Manchester', 'Liverpool', 'Munich'],
    "Found year" : [1899, 1902, 1880, 1892, 1900],
    "Coach" : ['Setien Kike', 'Zinedin Zidan', 'Josep Guardiola', 'Jurgen Klopp', 'Hans Flick'],
    "CL trophy" : [True, True, False, True, True],
    "Capital" : [3.16, 3.26, 1.38, 1.00, 2.35]
})

new_df
# Out:
#    Club name        City  Found year            Coach  CL trophy  Capital
# 0  Barcelona   Barcelona        1899      Setien Kike       True     3.16
# 1       Real      Madrid        1902    Zinedin Zidan       True     3.26
# 2       City  Manchester        1880  Josep Guardiola      False     1.38
# 3  Liverpool   Liverpool        1892     Jurgen Klopp       True     1.00
# 4     Bayern      Munich        1900       Hans Flick       True     2.35

# %%
# 2. Завантаження даних
# 2.1 Завантаження даних з вказанням повного шляху до файлу
path = "/Users/Alex/Desktop/FullData.csv"
data = pd.read_csv(path, encoding = 'utf-8')

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# 2.2 Завантаження файлу, що розміщений в робочій директорії
import os

print("The directory we are working in is: {}".format(os.getcwd()))
# Out:
# The directory we are working in is: C:\Users\Alex

# %%
data = pd.read_csv('FullData.csv')

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# 3. Відображення завантаження даних
data
# Out:
#                     Name          Nationality National_Position  National_Kit  \
# 0      Cristiano Ronaldo             Portugal                LS           7.0
# 1           Lionel Messi            Argentina                RW          10.0
# 2                 Neymar               Brazil                LW          10.0
# 3            Luis Suárez              Uruguay                LS           9.0
# 4           Manuel Neuer              Germany                GK           1.0
# ...                  ...                  ...               ...           ...
# 17583        Adam Dunbar  Republic of Ireland               NaN           NaN
# 17584       Dylan McGoey  Republic of Ireland               NaN           NaN
# 17585    Tommy Ouldridge              England               NaN           NaN
# 17586         Mark Foden             Scotland               NaN           NaN
# 17587   Barry Richardson              England               NaN           NaN
#
# ...

# %%
# 4. Базова статистика про завантажені дані
data.shape
# Out:
# (17588, 53)

# %%
data.head
# Out:
# <bound method NDFrame.head of                     Name          Nationality National_Position  National_Kit  \
# 0      Cristiano Ronaldo             Portugal                LS           7.0
# 1           Lionel Messi            Argentina                RW          10.0
# 2                 Neymar               Brazil                LW          10.0
# 3            Luis Suárez              Uruguay                LS           9.0
# 4           Manuel Neuer              Germany                GK           1.0
# ...                  ...                  ...               ...           ...
# 17583        Adam Dunbar  Republic of Ireland               NaN           NaN
# 17584       Dylan McGoey  Republic of Ireland               NaN           NaN
# 17585    Tommy Ouldridge              England               NaN           NaN
# 17586         Mark Foden             Scotland               NaN           NaN
# 17587   Barry Richardson              England               NaN           NaN
#
# ...

# %%
data.dtypes
# Out:
# Name                   object
# Nationality            object
# National_Position      object
# National_Kit          float64
# Club                   object
# Club_Position          object
# Club_Kit              float64
# Club_Joining           object
# Contract_Expiry       float64
# Rating                  int64
# Height                 object
# Weight                 object
# Preffered_Foot         object
# Birth_Date             object
# Age                     int64
# Preffered_Position     object
# Work_Rate              object
# Weak_foot               int64
# Skill_Moves             int64
# Ball_Control            int64
# Dribbling               int64
# Marking                 int64
# Sliding_Tackle          int64
# Standing_Tackle         int64
# Aggression              int64
# Reactions               int64
# Attacking_Position      int64
# Interceptions           int64
# Vision                  int64
# Composure               int64
# Crossing                int64
# ...

# %%
data.describe()
# Out:
#        National_Kit      Club_Kit  Contract_Expiry        Rating  \
# count   1075.000000  17587.000000     17587.000000  17588.000000
# mean      12.219535     21.294536      2018.899414     66.166193
# std        6.933187     19.163741         1.698787      7.083012
# min        1.000000      1.000000      2017.000000     45.000000
# 25%        6.000000      9.000000      2017.000000     62.000000
# 50%       12.000000     18.000000      2019.000000     66.000000
# 75%       18.000000     27.000000      2020.000000     71.000000
# max       36.000000     99.000000      2023.000000     94.000000
#
#                 Age     Weak_foot   Skill_Moves  Ball_Control     Dribbling  \
# count  17588.000000  17588.000000  17588.000000  17588.000000  17588.000000
# mean      25.460314      2.934103      2.303161     57.972766     54.802877
# std        4.680217      0.655927      0.746156     16.834779     18.913857
# ...

# %%
# 7. Використання функції desribe
data['Rating'].describe()
# Out:
# count    17588.000000
# mean        66.166193
# std          7.083012
# min         45.000000
# 25%         62.000000
# 50%         66.000000
# 75%         71.000000
# max         94.000000
# Name: Rating, dtype: float64

# %%
data['Freekick_Accuracy'].describe()
# Out:
# count    17588.000000
# mean        43.383443
# std         17.701903
# min          4.000000
# 25%         31.000000
# 50%         42.000000
# 75%         57.000000
# max         93.000000
# Name: Freekick_Accuracy, dtype: float64

# %%
cut_data = data.iloc[0:10, :]

cut_data
# Out:
#                  Name Nationality National_Position  National_Kit  \
# 0   Cristiano Ronaldo    Portugal                LS           7.0
# 1        Lionel Messi   Argentina                RW          10.0
# 2              Neymar      Brazil                LW          10.0
# 3         Luis Suárez     Uruguay                LS           9.0
# 4        Manuel Neuer     Germany                GK           1.0
# 5              De Gea       Spain                GK           1.0
# 6  Robert Lewandowski      Poland                LS           9.0
# 7         Gareth Bale       Wales                RS          11.0
# 8  Zlatan Ibrahimović      Sweden               NaN           NaN
# 9    Thibaut Courtois     Belgium                GK           1.0
#
#              Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  \
# 0     Real Madrid            LW       7.0   07/01/2009           2021.0
# 1    FC Barcelona            RW      10.0   07/01/2004           2018.0
# ...

# %%
new_data = ["group_1", "group_1", "group_1", "group_1", "group_1", "group_2", "group_2", "group_2", "group_2", "group_2"]
cut_data.insert(3, "Group", new_data)
cut_data
# Out:
#                  Name Nationality National_Position    Group  National_Kit  \
# 0   Cristiano Ronaldo    Portugal                LS  group_1           7.0
# 1        Lionel Messi   Argentina                RW  group_1          10.0
# 2              Neymar      Brazil                LW  group_1          10.0
# 3         Luis Suárez     Uruguay                LS  group_1           9.0
# 4        Manuel Neuer     Germany                GK  group_1           1.0
# 5              De Gea       Spain                GK  group_2           1.0
# 6  Robert Lewandowski      Poland                LS  group_2           9.0
# 7         Gareth Bale       Wales                RS  group_2          11.0
# 8  Zlatan Ibrahimović      Sweden               NaN  group_2           NaN
# 9    Thibaut Courtois     Belgium                GK  group_2           1.0
#
#              Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  ...  \
# ...

# %%
# Виведення статистики з розділенням на групи
cut_data.groupby('Group').describe()
# Out:
#         National_Kit                                           Club_Kit       \
#                count mean       std  min  25%  50%   75%   max    count mean
# Group
# group_1          5.0  7.4  3.781534  1.0  7.0  9.0  10.0  10.0      5.0  7.6
# group_2          4.0  5.5  5.259911  1.0  1.0  5.0   9.5  11.0      5.0  8.6
#
#          ... GK_Handling       GK_Reflexes                                    \
#          ...         75%   max       count  mean        std  min   25%   50%
# Group    ...
# group_1  ...        25.0  90.0         5.0  31.2  34.383135  8.0  11.0  11.0
# group_2  ...        85.0  91.0         5.0  41.4  43.963621  6.0  10.0  12.0
#
#
#           75%   max
# Group
# group_1  37.0  89.0
# group_2  89.0  90.0
#
# [2 rows x 328 columns]

# %%
cut_data.to_csv("output.csv", encoding='utf8')

# %%
final = data.describe()
final.to_csv("output_main.csv", encoding='utf8')
